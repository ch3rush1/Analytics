# %%
import pandas as pd

from bertopic import BERTopic
from transformers import pipeline
from sklearn.feature_extraction.text import CountVectorizer

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
df_main = pd.read_csv('reviews.csv.zip')

# %%
df_main.head()
# Out:
#         Time_submitted  ... Reply
# 0  2022-07-09 15:00:00  ...   NaN
# 1  2022-07-09 14:21:22  ...   NaN
# 2  2022-07-09 13:27:32  ...   NaN
# 3  2022-07-09 13:26:45  ...   NaN
# 4  2022-07-09 13:20:49  ...   NaN
#
# [5 rows x 5 columns]

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61594 entries, 0 to 61593
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time_submitted  61594 non-null  object
#  1   Review          61594 non-null  object
#  2   Rating          61594 non-null  int64
#  3   Total_thumbsup  61594 non-null  int64
#  4   Reply           216 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 2.3+ MB

# %%
# use only time submitted and reviews for analyses and final output
df = df_main.drop(['Rating','Total_thumbsup','Reply'], axis=1)
df.head()
# Out:
#         Time_submitted                                             Review
# 0  2022-07-09 15:00:00  Great music service, the audio is high quality...
# 1  2022-07-09 14:21:22  Please ignore previous negative rating. This a...
# 2  2022-07-09 13:27:32  This pop-up "Get the best Spotify experience o...
# 3  2022-07-09 13:26:45    Really buggy and terrible to use as of recently
# 4  2022-07-09 13:20:49  Dear Spotify why do I get songs that I didn't ...

# %% [markdown]
# ## Topic analysis

# %%
t_model = BERTopic(
    language='english', 
    embedding_model='all-MiniLM-L6-v2', 
    nr_topics='auto', 
    top_n_words=8, 
    calculate_probabilities=True, 
    verbose=True)

# %%
topics, probs = t_model.fit_transform(df['Review'])
# Out:
# Batches: 100%|██████████| 1925/1925 [00:35<00:00, 53.88it/s]
# 2022-11-22 23:54:52,533 - BERTopic - Transformed documents to Embeddings
# 2022-11-22 23:55:22,669 - BERTopic - Reduced dimensionality
# 2022-11-23 00:07:15,018 - BERTopic - Clustered reduced embeddings
# 2022-11-23 00:07:19,280 - BERTopic - Reduced number of topics from 391 to 191

# %%
t_model.get_topic_info().head()
# Out:
#    Topic  Count                                  Name
# 0     -1  27152                      -1_to_the_and_it
# 1      0   5589             0_love_music_best_spotify
# 2      1   4545                       1_ads_ad_30_too
# 3      2   2631            2_playlist_song_play_songs
# 4      3   2110  3_podcasts_podcast_episode_listening

# %%
gen_topic = t_model.get_topics()

# %%
gen_topic
# Out:
# {-1: [('to', 0.004957986270023924),
#   ('the', 0.004932824975719216),
#   ('and', 0.004901828184766566),
#   ('it', 0.00489113145943461),
#   ('app', 0.0047237839723945725),
#   ('music', 0.0046005728390924325),
#   ('is', 0.0045802088638491585),
#   ('you', 0.004492401766820211)],
#  0: [('love', 0.012299522934202615),
#   ('music', 0.011179164141198574),
#   ('best', 0.010782570181302064),
#   ('spotify', 0.010394649854181615),
#   ('easy', 0.009319947859039935),
#   ('app', 0.008413446116803308),
#   ('great', 0.008207941477388212),
#   ('use', 0.006866411473162016)],
#  1: [('ads', 0.030932098801262575),
#   ('ad', 0.017434187202798126),
#   ('30', 0.01045060238481711),
#   ('too', 0.009345399254742755),
#   ('many', 0.008638388919014627),
#   ('minutes', 0.00806949072566124),
#   ('after', 0.008004659735111545),
#   ('are', 0.007835183513949563)],
#  2: [('playlist', 0.014793923601259987),
#   ('song', 0.01221226061223215),
#   ('play', 0.010167697856024768),
#   ('songs', 0.009646484888232996),
#   ('want', 0.009570891087164867),
#   ('random', 0.008911448056771687),
#   ('plays', 0.007904238859596546),
#   ('listen', 0.0073061099323279526)],
#  3: [('podcasts', 0.032796111456253954),
#   ('podcast', 0.028236085195654043),
#   ('episode', 0.00785876844313496),
#   ('listening', 0.006497856246515869),
#   ('and', 0.006100748797132058),
#   ('for', 0.005682985187725171),
#   ('to', 0.00555260563486976),
#   ('great', 0.005373200319851784)],
#  4: [('premium', 0.023032605140291828),
#   ('free', 0.011101855474935245),
#   ('you', 0.008804914027573031),
#   ('worth', 0.008749476845269466),
#   ('without', 0.0077177960161397925),
#   ('version', 0.006925521532800716),
#   ('pay', 0.006733526854030299),
#   ('for', 0.006162937424453012)],
#  5: [('log', 0.03504214966255455),
#   ('account', 0.030620926652968592),
#   ('logged', 0.02570386241493442),
#   ('login', 0.02478695556993644),
#   ('password', 0.021839830945738877),
#   ('email', 0.021119739930304776),
#   ('out', 0.01675997278807936),
#   ('me', 0.014413658312560064)],
#  6: [('playing', 0.013148560033812814),
#   ('stop', 0.012390483194144623),
#   ('stops', 0.012260790868247926),
#   ('pause', 0.011425886411845039),
#   ('randomly', 0.010017744713648231),
#   ('keeps', 0.008547134308867926),
#   ('pausing', 0.00835204467098008),
#   ('stopping', 0.008210947992851943)],
#  7: [('crashing', 0.051916018413259137),
#   ('crashes', 0.039778395221824504),
#   ('keeps', 0.014959402728270467),
#   ('crash', 0.014043843295758685),
#   ('update', 0.009576642435173527),
#   ('constantly', 0.00949665164836574),
#   ('fix', 0.009456188385574753),
#   ('app', 0.007697596395328141)],
#  8: [('playlists', 0.03188732231214849),
#   ('playlist', 0.021770172350133503),
#   ('own', 0.01801207771503937),
#   ('love', 0.016526889920808346),
#   ('lists', 0.01649763098562185),
#   ('create', 0.01427362765168481),
#   ('easy', 0.012931418532452107),
#   ('make', 0.012403072582711689)],
#  9: [('bar', 0.06110716217968751),
#   ('disappears', 0.018557933135014668),
#   ('bottom', 0.01673280998121794),
#   ('disappearing', 0.015722197261296603),
#   ('playing', 0.015129407690486978),
#   ('pause', 0.01434576206636708),
#   ('update', 0.010804843268217089),
#   ('control', 0.010401385866365664)],
#  10: [('lyrics', 0.09126119476932955),
#   ('see', 0.008816474953518151),
#   ('feature', 0.00838160760151965),
#   ('still', 0.007790951845627328),
#   ('showing', 0.007402805857837034),
#   ('available', 0.007343105086669443),
#   ('but', 0.0070765683205313516),
#   ('the', 0.006965578074143652)],
#  11: [('streaming', 0.06963581944049255),
#   ('platform', 0.04531487176721568),
#   ('best', 0.035415346658115646),
#   ('service', 0.026860195402947214),
#   ('music', 0.016078592156727106),
#   ('ever', 0.009957372426046435),
#   ('great', 0.008917201043329803),
#   ('stream', 0.007950420586460451)],
#  12: [('stars', 0.03248915423289282),
#   ('star', 0.026186015111545252),
#   ('give', 0.015766686181837325),
#   ('rating', 0.012559402428217674),
#   ('five', 0.01255466022852319),
#   ('rate', 0.012426115541579396),
#   ('because', 0.012291813991652618),
#   ('would', 0.011336061740312773)],
#  13: [('offline', 0.052044121151050636),
#   ('downloaded', 0.030710663832668093),
#   ('mode', 0.018813993486256182),
#   ('download', 0.016865232377281103),
#   ('internet', 0.01297478601741777),
#   ('online', 0.01000649380683634),
#   ('connection', 0.008844119282766932),
#   ('when', 0.007836043274046162)],
#  14: [('internet', 0.05532512223431959),
#   ('connection', 0.04986883686069783),
#   ('wifi', 0.029520919613487174),
#   ('data', 0.018886839677169615),
#   ('no', 0.016935430003055776),
#   ('connected', 0.01678001734357863),
#   ('network', 0.014773018836915093),
#   ('working', 0.014330212742774542)],
#  15: [('shuffle', 0.06008110046286236),
#   ('same', 0.012626342971047158),
#   ('shuffling', 0.01110951059153416),
#   ('button', 0.009594580752102155),
#   ('turn', 0.009450330874241774),
#   ('play', 0.0091090788549506),
#   ('over', 0.008725572992371596),
#   ('playlist', 0.008603462383552857)],
#  16: [('bluetooth', 0.0524700175548778),
#   ('car', 0.023634134520604155),
#   ('connect', 0.015711400233273155),
#   ('auto', 0.013803141419800559),
#   ('pioneer', 0.0108667380601532),
#   ('kenwood', 0.010127473030429171),
#   ('autoplay', 0.009130560818496333),
#   ('connected', 0.00867463116932459)],
#  17: [('skips', 0.0352276971693962),
#   ('hour', 0.02665490329833588),
#   ('skip', 0.024990066228700897),
#   ('per', 0.017834190160401196),
#   ('you', 0.010604506181938518),
#   ('only', 0.010260259214917961),
#   ('want', 0.008541714425454336),
#   ('playlist', 0.008390439913253089)],
#  18: [('adds', 0.10790230990220742),
#   ('add', 0.028871659492884803),
#   ('too', 0.015625317222889894),
#   ('many', 0.01440948391276349),
#   ('are', 0.01149398217320321),
#   ('30', 0.011286723419298955),
#   ('there', 0.010202881087749383),
#   ('much', 0.010061160694914174)],
#  19: [('sound', 0.08721013940666418),
#   ('quality', 0.08393580896110345),
#   ('clear', 0.03382091715000945),
#   ('audio', 0.027513604797144642),
#   ('good', 0.01707459404961395),
#   ('great', 0.012638651181431622),
#   ('sounds', 0.012245103531152188),
#   ('excellent', 0.011154154128187625)],
#  20: [('search', 0.030809817105154565),
#   ('find', 0.024417814421921997),
#   ('available', 0.016638112752502834),
#   ('song', 0.01615592159391672),
#   ('songs', 0.014383571774435137),
#   ('searched', 0.013959000854618363),
#   ('all', 0.011530369452906019),
#   ('here', 0.010710517168111597)],
#  21: [('open', 0.044609799608269),
#   ('logo', 0.03078733337210703),
#   ('opening', 0.0258473492134316),
#   ('screen', 0.016903877122871794),
#   ('stuck', 0.0157470427430345),
#   ('working', 0.014838069664781711),
#   ('tried', 0.013466521678835318),
#   ('black', 0.012565941831080375)],
#  22: [('payment', 0.05206082056241538),
#   ('premium', 0.024762139471764765),
#   ('card', 0.022015819100810363),
#   ('unable', 0.020045398611915632),
#   ('connect', 0.018021030324273705),
#   ('subscribe', 0.015561844596772552),
#   ('plan', 0.01517402567462938),
#   ('method', 0.014087746403560931)],
#  23: [('payment', 0.03431401612779251),
#   ('account', 0.016897788077758744),
#   ('premium', 0.016313192237597095),
#   ('card', 0.016266558194835756),
#   ('plan', 0.012495729525447453),
#   ('spotify', 0.01159684023190885),
#   ('bank', 0.011506001786517145),
#   ('method', 0.01119606359480167)],
#  24: [('language', 0.05837399251699967),
#   ('english', 0.054315681742717024),
#   ('lyrics', 0.053840010924626786),
#   ('korean', 0.03336629862695026),
#   ('tamil', 0.031028045876304818),
#   ('kannada', 0.030507583434617912),
#   ('languages', 0.028940539075933545),
#   ('telugu', 0.015961607511787473)],
#  25: [('button', 0.04028166859610249),
#   ('buttons', 0.03080812284720241),
#   ('left', 0.03070240795649723),
#   ('ui', 0.028216613555956668),
#   ('layout', 0.02409431757476575),
#   ('pause', 0.017961933809877234),
#   ('landscape', 0.015416232265174513),
#   ('design', 0.015136858251663693)],
#  26: [('rogan', 0.05013542169278686),
#   ('joe', 0.04937377987138236),
#   ('speech', 0.035057967786491874),
#   ('his', 0.016787955975460473),
#   ('him', 0.015056317084180856),
#   ('censorship', 0.014131060770420008),
#   ('spotify', 0.013376338338439764),
#   ('support', 0.013358826622509725)],
#  27: [('preview', 0.08691224068837586),
#   ('adding', 0.03145011429383692),
#   ('add', 0.022961174566095335),
#   ('bring', 0.020459887960968506),
#   ('feature', 0.020324263487700014),
#   ('before', 0.017882257340776374),
#   ('previews', 0.016719557805080436),
#   ('playlist', 0.01621152336154002)],
#  28: [('rogan', 0.08927416138959869),
#   ('joe', 0.07570615697292134),
#   ('podcast', 0.01820907994564539),
#   ('episodes', 0.01666124737757055),
#   ('his', 0.013966094252088897),
#   ('he', 0.013254061464733428),
#   ('video', 0.009794526034860408),
#   ('podcasts', 0.009172333274785015)],
#  29: [('scroll', 0.083680894612946),
#   ('liked', 0.04372872070553703),
#   ('scrolling', 0.022845515719885603),
#   ('bar', 0.019052006641022756),
#   ('filter', 0.017993444284052477),
#   ('genre', 0.01752971897581647),
#   ('through', 0.01733377731171704),
#   ('slider', 0.016714706642219225)],
#  30: [('subscription', 0.016933186604814496),
#   ('premium', 0.014677274945307408),
#   ('cancel', 0.0118133324269083),
#   ('bugs', 0.009441723649501733),
#   ('app', 0.009277900315225315),
#   ('service', 0.008312471898105299),
#   ('for', 0.008294214623821688),
#   ('month', 0.008256998419839335)],
#  31: [('pandora', 0.1154025576889891),
#   ('better', 0.03071020538332869),
#   ('than', 0.02368230413071651),
#   ('way', 0.007613336622806521),
#   ('more', 0.007478346452569173),
#   ('was', 0.007145910212170352),
#   ('this', 0.007141561938436895),
#   ('much', 0.006750225436880046)],
#  32: [('glitches', 0.058569122226334355),
#   ('glitchy', 0.039874869188233845),
#   ('glitching', 0.03616542904790611),
#   ('works', 0.018421985198620743),
#   ('glitch', 0.01613663318505773),
#   ('great', 0.011692674033269911),
#   ('sometimes', 0.010548935406881661),
#   ('problems', 0.009852183511597832)],
#  33: [('bar', 0.03972167025929157),
#   ('playing', 0.01306936256439584),
#   ('pause', 0.011591316328296535),
#   ('disappears', 0.009638024999268531),
#   ('spotify', 0.00952969660664661),
#   ('stop', 0.008728376575581849),
#   ('disappearing', 0.008682624138205955),
#   ('play', 0.008362746763893723)],
#  34: [('controls', 0.07664197794848919),
#   ('disappear', 0.029411081224637765),
#   ('disappearing', 0.020009756724049747),
#   ('control', 0.01598919306410321),
#   ('player', 0.012180836450090042),
#   ('android', 0.01204416114398946),
#   ('playback', 0.011514266005545643),
#   ('pause', 0.011063878991198834)],
#  35: [('commercials', 0.21212212835487906),
#   ('spanish', 0.037214357716078436),
#   ('commercial', 0.03465041534824109),
#   ('many', 0.022396208670440475),
#   ('too', 0.013656202724149734),
#   ('no', 0.01272767151520297),
#   ('love', 0.00993750682104752),
#   ('depravity', 0.009469233309211655)],
#  36: [('sort', 0.03543692382980578),
#   ('order', 0.03370822239284671),
#   ('rearrange', 0.020548552687170128),
#   ('playlist', 0.02009195423389069),
#   ('by', 0.01725236361765496),
#   ('sorting', 0.01543149036955276),
#   ('option', 0.015200803281388337),
#   ('playlists', 0.01497338294966893)],
#  37: [('empty', 0.031128787672077197),
#   ('playlists', 0.028968327668405788),
#   ('all', 0.01174506284583305),
#   ('my', 0.01093297588069323),
#   ('anything', 0.0101436782593153),
#   ('gone', 0.009782302502739489),
#   ('playlist', 0.007749946234511197),
#   ('fine', 0.007612943435520663)],
#  38: [('collection', 0.23036937489677106),
#   ('collections', 0.05638977616930115),
#   ('best', 0.04129780833425564),
#   ('excellent', 0.03307449180619113),
#   ('good', 0.03158799899178581),
#   ('songs', 0.02471837963562047),
#   ('nice', 0.0222814586221363),
#   ('of', 0.017651954659160828)],
#  39: [('misinformation', 0.05394741226637903),
#   ('culture', 0.023122235885487046),
#   ('platform', 0.022239967716189826),
#   ('cancel', 0.02032239941913804),
#   ('covid', 0.01773160878127882),
#   ('their', 0.0162184807671937),
#   ('support', 0.015639215654768796),
#   ('spotify', 0.015234059134888763)],
#  40: [('art', 0.0417414190526975),
#   ('album', 0.03713700977862026),
#   ('artists', 0.03302253126335378),
#   ('artwork', 0.01867345507151508),
#   ('artist', 0.01718172943151722),
#   ('covers', 0.016555267493727023),
#   ('cover', 0.015929830363853748),
#   ('images', 0.013788389492227647)],
#  41: [('service', 0.08655052952201887),
#   ('great', 0.0178049238802579),
#   ('misinformation', 0.016171899624315162),
#   ('customer', 0.011569579621972758),
#   ('excellent', 0.011393373655210561),
#   ('year', 0.010634226451540335),
#   ('round', 0.010632673633165267),
#   ('worth', 0.010505724599818538)],
#  42: [('load', 0.03237863418615257),
#   ('slow', 0.02139642602918706),
#   ('downloaded', 0.016541306493448392),
#   ('loading', 0.01585100687471452),
#   ('takes', 0.014523114533149018),
#   ('playlists', 0.01063790940337887),
#   ('forever', 0.010138310224330444),
#   ('internet', 0.009286140232287122)],
#  43: [('swipe', 0.12093482631244823),
#   ('queue', 0.08242902487865489),
#   ('ios', 0.05178927005078443),
#   ('android', 0.029734222193141896),
#   ('add', 0.02617112495505121),
#   ('finally', 0.024663473356744844),
#   ('feature', 0.022661976730326123),
#   ('gesture', 0.022140520877046984)],
#  44: [('home', 0.03432425261401158),
#   ('podcasts', 0.03316364521060315),
#   ('remove', 0.026266587569162652),
#   ('page', 0.023298788133645713),
#   ('hide', 0.02215032129549401),
#   ('podcast', 0.022011926652403813),
#   ('homepage', 0.02156032153723776),
#   ('disable', 0.014541398085529346)],
#  45: [('group', 0.12561942240326274),
#   ('session', 0.11269416083629356),
#   ('sessions', 0.055892052881395156),
#   ('join', 0.05414028645446244),
#   ('scan', 0.026963074110106657),
#   ('scanning', 0.022103397269162904),
#   ('link', 0.01597957411142297),
#   ('device', 0.015369571558854784)],
#  46: [('cancel', 0.07485871199442493),
#   ('subscription', 0.026892781540315117),
#   ('charged', 0.018302762503777294),
#   ('unsubscribe', 0.01789609570559282),
#   ('card', 0.013304361269196959),
#   ('account', 0.013244781908055768),
#   ('they', 0.012406064039529765),
#   ('payment', 0.010942897749811213)],
#  47: [('india', 0.0655838257838288),
#   ('hindi', 0.03728623599851573),
#   ('punjabi', 0.029548852585857842),
#   ('hai', 0.026314513845723884),
#   ('indian', 0.02549957628712358),
#   ('available', 0.019085401977970446),
#   ('language', 0.016537446500415463),
#   ('ke', 0.015832229445295606)],
#  48: [('queue', 0.11350373657698541),
#   ('add', 0.025214512056541752),
#   ('queued', 0.01614561339248937),
#   ('next', 0.011405969894435857),
#   ('album', 0.010179539369865407),
#   ('option', 0.009894768594875716),
#   ('added', 0.00982857812494269),
#   ('from', 0.009523873176571374)],
#  49: [('application', 0.19899734441766984),
#   ('best', 0.027100403860000948),
#   ('music', 0.01931626254015612),
#   ('program', 0.01880524044462705),
#   ('referral', 0.016792358075182496),
#   ('applications', 0.016749814406560353),
#   ('variety', 0.01633379895312698),
#   ('ever', 0.015067381194236338)],
#  50: [('pandora', 0.10961399351908065),
#   ('better', 0.019412177493565243),
#   ('spotify', 0.01583478207968888),
#   ('than', 0.013084929442208893),
#   ('switched', 0.009899002604846859),
#   ('used', 0.009711877695171473),
#   ('years', 0.009276001027593597),
#   ('love', 0.008041492289898648)],
#  51: [('liked', 0.07473146084868931),
#   ('songs', 0.019164925356494313),
#   ('list', 0.017069528889286124),
#   ('added', 0.011620628481712289),
#   ('heart', 0.010240867399022871),
#   ('from', 0.010166098911951653),
#   ('removed', 0.00988857545698765),
#   ('my', 0.009659072136735839)],
#  52: [('lisa', 0.11504190933270877),
#   ('replaced', 0.05306517223620526),
#   ('money', 0.04249705994338054),
#   ('tth', 0.04072343432321561),
#   ('unauthorized', 0.036303185159862195),
#   ('by', 0.034407163651695785),
#   ('hacked', 0.029917422155771603),
#   ('identical', 0.02677497455007909)],
#  53: [('algorithm', 0.08397090228069011),
#   ('algorithms', 0.04618483681136126),
#   ('tastes', 0.011065009818103872),
#   ('follow', 0.010031656383115798),
#   ('your', 0.009985896265830125),
#   ('playlists', 0.009703879644331462),
#   ('recommendations', 0.009302012968045776),
#   ('create', 0.009241371664451742)],
#  54: [('closes', 0.041453847560785635),
#   ('closed', 0.03788739211912916),
#   ('automatically', 0.024866416846381217),
#   ('closing', 0.022622898433722293),
#   ('close', 0.015979200535584343),
#   ('whenever', 0.014783494562753317),
#   ('itself', 0.014607898206055679),
#   ('shuts', 0.013966910785861866)],
#  55: [('playlist', 0.019023765559825247),
#   ('add', 0.01767966236907833),
#   ('songs', 0.014445747854174674),
#   ('added', 0.01163697162482901),
#   ('extra', 0.010763560216715536),
#   ('it', 0.010527594462972),
#   ('that', 0.010009987312605653),
#   ('trim', 0.009951978115244488)],
#  56: [('car', 0.1050669612353003),
#   ('mode', 0.053613794993721875),
#   ('view', 0.022315255322415673),
#   ('driving', 0.020834233624605465),
#   ('removing', 0.014165152218978813),
#   ('removed', 0.011007161812771208),
#   ('thing', 0.010577669372539313),
#   ('while', 0.010260315378437388)],
#  57: [('empty', 0.031195614534113052),
#   ('playlists', 0.017353865826329147),
#   ('nothing', 0.015489276435928758),
#   ('working', 0.012337203120830175),
#   ('any', 0.011394219322381435),
#   ('my', 0.010938137076104979),
#   ('playlist', 0.010776599412723947),
#   ('spotify', 0.010680992350789663)],
#  58: [('mobile', 0.0668424491011482),
#   ('pc', 0.06326662784068252),
#   ('version', 0.025758267608161235),
#   ('desktop', 0.02220808201673459),
#   ('on', 0.01699077681474573),
#   ('can', 0.011410556424270784),
#   ('song', 0.010548074015252814),
#   ('want', 0.00945663183022584)],
#  59: [('slow', 0.10063705485288518),
#   ('takes', 0.0594855510039242),
#   ('loading', 0.054673259006368276),
#   ('load', 0.053048149993489266),
#   ('forever', 0.023312691959690327),
#   ('slower', 0.018117167176122467),
#   ('connection', 0.016556475065872833),
#   ('optimize', 0.01462668745320689)],
#  60: [('navigate', 0.3110142844443235),
#   ('easy', 0.12203477595085747),
#   ('navigation', 0.028906641651990698),
#   ('friendly', 0.020798586111422705),
#   ('far', 0.01967658593661085),
#   ('tyriuggt', 0.018805753019445322),
#   ('very', 0.01783181843620113),
#   ('use', 0.0172296065669158)],
#  61: [('experience', 0.1668983602126008),
#   ('best', 0.05181737695287611),
#   ('ever', 0.036375775093356745),
#   ('music', 0.03397580190905584),
#   ('rock', 0.026405304910274725),
#   ('provide', 0.025911049194748022),
#   ('great', 0.02471787615799493),
#   ('amazing', 0.022253114695013437)],
#  62: [('downloaded', 0.0336566015402972),
#   ('redownload', 0.030703932223524733),
#   ('deletes', 0.022383502112637378),
#   ('downloads', 0.022239853105275587),
#   ('deleting', 0.021835738829417906),
#   ('download', 0.018002498058845302),
#   ('redownloading', 0.013766293182561852),
#   ('space', 0.012723651317924406)],
#  63: [('live', 0.15042774408500006),
#   ('without', 0.09398056914516642),
#   ('life', 0.04537237655441698),
#   ('couldn', 0.043311510340498925),
#   ('spotify', 0.035639739674318896),
#   ('survive', 0.029689191617470915),
#   ('love', 0.0172697835433778),
#   ('would', 0.01645820593594613)],
#  64: [('alexa', 0.15417980633284759),
#   ('echo', 0.042183813085704056),
#   ('devices', 0.03475748383128096),
#   ('connect', 0.0287866366294439),
#   ('device', 0.019536536837330337),
#   ('amazon', 0.01813227425050258),
#   ('compatible', 0.013482456981042447),
#   ('unlinking', 0.012817232339630951)],
#  65: [('jre', 0.1079055488438445),
#   ('podcast', 0.020791555006611968),
#   ('video', 0.016801317692096775),
#   ('constantly', 0.011326296618704925),
#   ('episode', 0.011112761075007515),
#   ('podcasts', 0.010807206835024214),
#   ('pauses', 0.009550583310780819),
#   ('progress', 0.009048735131243603)],
#  66: [('library', 0.20716480088059444),
#   ('extensive', 0.030326326716522516),
#   ('large', 0.030192070965076104),
#   ('excellent', 0.023097475682835957),
#   ('musical', 0.02297870354747223),
#   ('massive', 0.017376309306838342),
#   ('chart', 0.01661744721354623),
#   ('overplay', 0.01661744721354623)],
#  67: [('working', 0.05902485442915999),
#   ('spotify', 0.028106915261472507),
#   ('tried', 0.021674739176665046),
#   ('work', 0.021619578429812162),
#   ('not', 0.021017488464535047),
#   ('phone', 0.018850994460402407),
#   ('why', 0.01745478780376886),
#   ('properly', 0.016761339869746303)],
#  68: [('widget', 0.17446861427033972),
#   ('widgets', 0.06930361067883826),
#   ('home', 0.027422789555087652),
#   ('screen', 0.021636962717275898),
#   ('looks', 0.0168510492681463),
#   ('update', 0.01603120951495527),
#   ('homescreen', 0.015494093853047479),
#   ('working', 0.014494451209386765)],
#  69: [('volume', 0.17903473307053563),
#   ('low', 0.03768540088149309),
#   ('level', 0.019501587339158594),
#   ('equalizer', 0.019286807614740928),
#   ('turning', 0.016366397708630215),
#   ('adjust', 0.016096128935595727),
#   ('speaker', 0.01568699195140295),
#   ('down', 0.01553952593804418)],
#  70: [('timer', 0.14806309538007437),
#   ('sleep', 0.13711995566020704),
#   ('custom', 0.021913764353943318),
#   ('sleeping', 0.018724574462347765),
#   ('hour', 0.017731100946789067),
#   ('end', 0.016923420387342604),
#   ('set', 0.016736304639741593),
#   ('bed', 0.016049880430165957)],
#  71: [('fancy', 0.04986858347389002),
#   ('tickle', 0.043651452774247014),
#   ('very', 0.0422987321044771),
#   ('listening', 0.037538003170092864),
#   ('good', 0.029825389089248144),
#   ('efficient', 0.02950296387957332),
#   ('for', 0.02922536431239654),
#   ('perfect', 0.029138820047203435)],
#  72: [('casting', 0.1017938940081659),
#   ('cast', 0.09860239195746315),
#   ('chromecast', 0.07932362906738613),
#   ('tv', 0.05242150576994015),
#   ('roku', 0.03809594234575413),
#   ('chrome', 0.036851703138854996),
#   ('devices', 0.01709129350440056),
#   ('work', 0.016134695952904215)],
#  73: [('missing', 0.08622421802568286),
#   ('available', 0.056855888545484526),
#   ('some', 0.05510481694114605),
#   ('are', 0.032171421531731026),
#   ('artists', 0.021124471529740157),
#   ('songs', 0.02089538894767837),
#   ('albums', 0.01937614007180443),
#   ('not', 0.01775816265200763)],
#  74: [('canvas', 0.19503364344958946),
#   ('option', 0.03843842201878288),
#   ('feature', 0.022970509874689144),
#   ('activate', 0.018914478665866034),
#   ('india', 0.018230859496493293),
#   ('version', 0.015669818597678145),
#   ('nepal', 0.014867926263777077),
#   ('settings', 0.014803815201384109)],
#  75: [('genres', 0.10972519943389307),
#   ('genre', 0.06574692935058696),
#   ('great', 0.02295506796308555),
#   ('wide', 0.02203339256963421),
#   ('50s', 0.02166374311131294),
#   ('all', 0.018391543163460748),
#   ('suggest', 0.018287879346235884),
#   ('music', 0.01636068256255107)],
#  76: [('sd', 0.13320888853856122),
#   ('storage', 0.09712281867876085),
#   ('card', 0.0878467746856854),
#   ('internal', 0.05468310336172873),
#   ('reboot', 0.027043449276231785),
#   ('location', 0.026323360566107203),
#   ('downloads', 0.019608325667755295),
#   ('external', 0.019538078695615503)],
#  77: [('doki', 0.1691234840353488),
#   ('awesome', 0.07628594445844152),
#   ('ddlc', 0.07222633218967855),
#   ('literature', 0.050578180310280225),
#   ('club', 0.04400223357906965),
#   ('spotify', 0.041588136294070994),
#   ('amazing', 0.030847880550273116),
#   ('exsperience', 0.027364059782785707)],
#  78: [('watch', 0.14398516718139276),
#   ('galaxy', 0.0545672512540691),
#   ('speaker', 0.022609054970354665),
#   ('bluetooth', 0.0193440805896364),
#   ('smartwatch', 0.01746308027652715),
#   ('samsung', 0.014859685580720521),
#   ('soundbar', 0.013258364908685155),
#   ('bud', 0.012784210299356547)],
#  79: [('logo', 0.14765041787437747),
#   ('stuck', 0.0494716157314797),
#   ('open', 0.02936437369589561),
#   ('screen', 0.026186741123813306),
#   ('cache', 0.023301461812474614),
#   ('tried', 0.020894491614446464),
#   ('opening', 0.017514413860377744),
#   ('reinstalling', 0.017012569348064204)],
#  80: [('moment', 0.024102868089159055),
#   ('problems', 0.01867515168027755),
#   ('had', 0.015786892045938083),
#   ('years', 0.015096485609501267),
#   ('app', 0.014650067418628268),
#   ('giid', 0.014576708082058095),
#   ('naver', 0.014576708082058095),
#   ('tonuninstall', 0.014576708082058095)],
#  81: [('player', 0.09600404504908955),
#   ('disappears', 0.03036785530495783),
#   ('visible', 0.020980247666281867),
#   ('disappearing', 0.018774783709955698),
#   ('restart', 0.016184939937006156),
#   ('vanishing', 0.01487345085765871),
#   ('fixed', 0.01482030426537437),
#   ('bug', 0.014305031648588588)],
#  82: [('interface', 0.22235077840366418),
#   ('easy', 0.07169714321471671),
#   ('user', 0.05776730033348353),
#   ('intuitive', 0.04223794204006998),
#   ('use', 0.03864275977627761),
#   ('organized', 0.03439548632884149),
#   ('very', 0.0338405755626309),
#   ('features', 0.03073923101535865)],
#  83: [('bts', 0.2192461693377851),
#   ('blackpink', 0.03869224325122844),
#   ('army', 0.0341059983374717),
#   ('opinión', 0.026774245229026234),
#   ('rm', 0.01874929214609722),
#   ('best', 0.016944820775327562),
#   ('available', 0.014841847931074317),
#   ('this', 0.014177579442594655)],
#  84: [('enhance', 0.2070292350335908),
#   ('feature', 0.06006722514151341),
#   ('button', 0.03696567589745331),
#   ('enhanced', 0.03155285489145814),
#   ('liked', 0.028964534679360013),
#   ('new', 0.022039394300319218),
#   ('remove', 0.01879051966504568),
#   ('dissapeared', 0.018432800195220093)],
#  85: [('relaxing', 0.04935119722476233),
#   ('stress', 0.045509585131483725),
#   ('relax', 0.0443896728392541),
#   ('mood', 0.03515704727312583),
#   ('helps', 0.032903897138857954),
#   ('calm', 0.02897303208407231),
#   ('sad', 0.027979782192000726),
#   ('depressed', 0.02398511444613432)],
#  86: [('track', 0.018156410995414946),
#   ('skip', 0.016455138990953484),
#   ('previous', 0.01395133398372892),
#   ('song', 0.012294436871794167),
#   ('skips', 0.010115100539913395),
#   ('ahead', 0.00964641483562416),
#   ('or', 0.009615393564565564),
#   ('next', 0.009390457142005423)],
#  87: [('works', 0.05808423424526065),
#   ('download', 0.01991402950776557),
#   ('great', 0.01939724857822314),
#   ('teued', 0.015490840622797332),
#   ('helo', 0.015490840622797332),
#   ('cracced', 0.015490840622797332),
#   ('foriegn', 0.015490840622797332),
#   ('fixture', 0.015490840622797332)],
#  88: [('download', 0.0815780413788001),
#   ('album', 0.07824162529033851),
#   ('individual', 0.030460750587731737),
#   ('single', 0.029713272618833553),
#   ('option', 0.02087724743912023),
#   ('entire', 0.017314534771607666),
#   ('particular', 0.015910555398829355),
#   ('whole', 0.0157468020516686)],
#  89: [('aap', 0.3327132681383438),
#   ('vary', 0.023563068733115523),
#   ('best', 0.020732324169704143),
#   ('pahari', 0.017375657732795487),
#   ('mounam', 0.017375657732795487),
#   ('assoommm', 0.017375657732795487),
#   ('minea', 0.017375657732795487),
#   ('ets', 0.017375657732795487)],
#  90: [('equalizer', 0.1491294180118126),
#   ('equaliser', 0.05619942652172662),
#   ('settings', 0.035055556616198115),
#   ('bass', 0.021768531755223572),
#   ('android', 0.015343565246850143),
#   ('pro', 0.014794071391271035),
#   ('equilizer', 0.014330711387359744),
#   ('mi', 0.013572618678017387)],
#  91: [('s22', 0.11045369093375892),
#   ('ultra', 0.06955626029169658),
#   ('galaxy', 0.022983805268034167),
#   ('playing', 0.016041585255662582),
#   ('changed', 0.01491078034106129),
#   ('samsung', 0.01415708341926955),
#   ('restart', 0.013652706167408588),
#   ('pause', 0.013374107172293133)],
#  92: [('show', 0.029401715324748418),
#   ('bottom', 0.026864476153138053),
#   ('notification', 0.025162593114605288),
#   ('playing', 0.01888478966635795),
#   ('close', 0.01637198981631073),
#   ('currently', 0.015709722172616035),
#   ('showing', 0.014187391855868958),
#   ('or', 0.012474174525461774)],
#  93: [('speech', 0.15809245356035118),
#   ('standing', 0.06496126630673574),
#   ('freedom', 0.05087001597105099),
#   ('free', 0.04938539090542768),
#   ('expression', 0.040762600785767884),
#   ('states', 0.03432414371500172),
#   ('supreme', 0.031472400458385695),
#   ('york', 0.029473922840027617)],
#  94: [('lock', 0.04620485457334503),
#   ('locked', 0.04255872072197354),
#   ('phone', 0.03382733734400771),
#   ('screen', 0.026466461851281094),
#   ('stops', 0.023060164911719222),
#   ('playing', 0.01669703434174523),
#   ('last', 0.01515076723153403),
#   ('unlock', 0.014468414908851073)],
#  95: [('drive', 0.089537959932804),
#   ('notification', 0.08311350011515099),
#   ('notifications', 0.06468708933429432),
#   ('going', 0.0375827729120433),
#   ('disable', 0.035612557491209194),
#   ('push', 0.023741704994139468),
#   ('off', 0.023428719760611803),
#   ('annoying', 0.021146189526170246)],
#  96: [('covid', 0.06441191720308018),
#   ('podcast', 0.02839854498829743),
#   ('censorship', 0.023370340455960172),
#   ('news', 0.018916601725929506),
#   ('warnings', 0.01846807828171812),
#   ('misinformation', 0.017255184766613786),
#   ('censor', 0.016210096947056944),
#   ('warning', 0.014598810051491573)],
#  97: [('youtube', 0.10488010090641743),
#   ('better', 0.0373634724326644),
#   ('distortion', 0.025277704505283338),
#   ('spikes', 0.02015884513560095),
#   ('spotify', 0.0189436584005724),
#   ('than', 0.015933455677752832),
#   ('edition', 0.015885129495948145),
#   ('fell', 0.01466802124203437)],
#  98: [('light', 0.13473886122092707),
#   ('dark', 0.11665066076130927),
#   ('theme', 0.09769039347807751),
#   ('mode', 0.0871474843002521),
#   ('wonderfully', 0.022992775347900084),
#   ('themes', 0.02205628825702633),
#   ('black', 0.021842895890189666),
#   ('option', 0.016688009559436626)],
#  99: [('free', 0.05877022532061841),
#   ('should', 0.023890072293307685),
#   ('better', 0.018472324423936735),
#   ('mp3', 0.01765469719872778),
#   ('might', 0.016408264337919892),
#   ('stations', 0.016268168514188483),
#   ('datavoliums', 0.016176276048584824),
#   ('11544', 0.016176276048584824)],
#  100: [('download', 0.038706813868043886),
#   ('premium', 0.03565173056021865),
#   ('unable', 0.023761992014929928),
#   ('paid', 0.021859743174545324),
#   ('some', 0.021736944141815602),
#   ('subsecribe', 0.0191605785481141),
#   ('withouy', 0.0191605785481141),
#   ('evenn', 0.0191605785481141)],
#  101: [('session', 0.09694047976093724),
#   ('group', 0.06629254464105337),
#   ('join', 0.05278152844466826),
#   ('sessions', 0.04769623121663342),
#   ('scan', 0.0454956615300121),
#   ('invite', 0.03851504592917351),
#   ('link', 0.017975232650853146),
#   ('remote', 0.0178601681598589)],
#  102: [('works', 0.042041340244116106),
#   ('experience', 0.032502183292716785),
#   ('far', 0.030166627019535874),
#   ('weeks', 0.029812535305624846),
#   ('rawn', 0.028831533020348344),
#   ('stages', 0.028831533020348344),
#   ('appreciative', 0.02664528741898043),
#   ('withdraw', 0.02664528741898043)],
#  103: [('laggy', 0.10986545034799368),
#   ('lag', 0.0914779423432229),
#   ('lags', 0.07296059042413458),
#   ('lagging', 0.052809005109195804),
#   ('unresponsivness', 0.02531744035304827),
#   ('raises', 0.023397662359603316),
#   ('processor', 0.023397662359603316),
#   ('booting', 0.023397662359603316)],
#  104: [('worst', 0.08204693716621393),
#   ('ads', 0.02757325254916228),
#   ('ever', 0.024267988282743767),
#   ('thn', 0.021701980650222063),
#   ('bad', 0.014609870366774691),
#   ('mtlbb', 0.013169446638977558),
#   ('krta', 0.013169446638977558),
#   ('affiliation', 0.013169446638977558)],
#  105: [('freezes', 0.04174134908191793),
#   ('freezing', 0.03520454345099568),
#   ('playing', 0.013398656510774404),
#   ('up', 0.012351954148122143),
#   ('occurs', 0.012340386516887156),
#   ('open', 0.011846924804393782),
#   ('issue', 0.011378528340748682),
#   ('or', 0.010501021919196602)],
#  106: [('queue', 0.1029000154705672),
#   ('functionality', 0.017338444684915036),
#   ('custoner', 0.013641188011120037),
#   ('dur', 0.013641188011120037),
#   ('cast', 0.013259113403235271),
#   ('timer', 0.013154702346807866),
#   ('button', 0.012836836704687766),
#   ('awesomeness', 0.012001788533011263)],
#  107: [('apple', 0.23878713865508866),
#   ('better', 0.06668922236117734),
#   ('than', 0.06161841184005657),
#   ('music', 0.03054906250709005),
#   ('10000000000', 0.029199987116455033),
#   ('here', 0.028812317749360907),
#   ('2years', 0.026985802274175068),
#   ('1yr', 0.026985802274175068)],
#  108: [('update', 0.02981224279139483),
#   ('new', 0.026534708446093687),
#   ('rlly', 0.021686509082584866),
#   ('tf', 0.021170350609017334),
#   ('pls', 0.01501949734964532),
#   ('this', 0.014636628032197794),
#   ('hate', 0.014092747196560925),
#   ('fav', 0.013743617341674149)],
#  109: [('pod', 0.2768736324563794),
#   ('casts', 0.15961886881641982),
#   ('cast', 0.13392370824373315),
#   ('truth', 0.02852855172290966),
#   ('great', 0.02464689876773507),
#   ('revealed', 0.02296380896344328),
#   ('cavern', 0.02296380896344328),
#   ('kincade', 0.02296380896344328)],
#  110: [('misinformation', 0.14871478829782603),
#   ('covid', 0.07401836808491413),
#   ('spreads', 0.054893767082905345),
#   ('spreading', 0.044786044854198806),
#   ('support', 0.03808229626449886),
#   ('platform', 0.03553952572997576),
#   ('proved', 0.031053968188152814),
#   ('researching', 0.030302569103936625)],
#  111: [('finding', 0.020362116553958306),
#   ('party', 0.019649949108942674),
#   ('wonderful', 0.018899045799863887),
#   ('nugget', 0.018170170909444183),
#   ('njoy', 0.018170170909444183),
#   ('comparely', 0.018170170909444183),
#   ('communities', 0.018170170909444183),
#   ('refix', 0.018170170909444183)],
#  112: [('repeat', 0.16729790167703315),
#   ('button', 0.04465209572597062),
#   ('cant', 0.019749330975664378),
#   ('fix', 0.01708788035975198),
#   ('15', 0.015982942187698874),
#   ('repeats', 0.015389393615915483),
#   ('option', 0.015248468798718448),
#   ('everythinf', 0.014599993558227517)],
#  113: [('pay', 0.032205511886940666),
#   ('worth', 0.027294484494285832),
#   ('compares', 0.024982707837405093),
#   ('best', 0.023292665562312267),
#   ('penny', 0.01988400042288364),
#   ('fee', 0.018508787227591927),
#   ('music', 0.01796778558982622),
#   ('mountian', 0.017746788286311505)],
#  114: [('commercials', 0.12512857204121944),
#   ('commercial', 0.03828427393554631),
#   ('brain', 0.01679273177714683),
#   ('vehicle', 0.014648163025817606),
#   ('word', 0.014370099353266802),
#   ('succumb', 0.013207508623483273),
#   ('microaggressive', 0.013207508623483273),
#   ('commercialism', 0.013207508623483273)],
#  115: [('s22', 0.2364972962217723),
#   ('ultra', 0.15769058155873947),
#   ('samsung', 0.038514526943192295),
#   ('slower', 0.03619562245656945),
#   ('opening', 0.03391733607192382),
#   ('glitchy', 0.030379026942446107),
#   ('s21', 0.029071482876082078),
#   ('s22u', 0.02707229523018204)],
#  116: [('place', 0.19592680798856144),
#   ('venue', 0.08115983285604382),
#   ('concerts', 0.049823241105181076),
#   ('nough', 0.035017609070691284),
#   ('reminiscence', 0.035017609070691284),
#   ('lease', 0.030809188954473356),
#   ('where', 0.03074366189886796),
#   ('side', 0.02978700953194359)],
#  117: [('hidden', 0.10286498281193926),
#   ('unhide', 0.09920993617052996),
#   ('hiding', 0.023449571563073167),
#   ('hide', 0.023193486273936234),
#   ('tapped', 0.01624400282256719),
#   ('option', 0.015012647131844426),
#   ('mistake', 0.013769106990216414),
#   ('discovery', 0.013664803461296999)],
#  118: [('words', 0.3193392121306126),
#   ('exceptional', 0.09972790098693621),
#   ('amazing', 0.08405867683745752),
#   ('word', 0.0695392220451792),
#   ('generously', 0.06391325851363934),
#   ('expressd', 0.06391325851363934),
#   ('expeeience', 0.06391325851363934),
#   ('excitingly', 0.06391325851363934)],
#  119: [('update', 0.024497569552193267),
#   ('skip', 0.01803225744681015),
#   ('playing', 0.01423636503869219),
#   ('scroll', 0.012899022096927774),
#   ('fail', 0.012156612166822282),
#   ('stops', 0.011634171972105853),
#   ('broken', 0.011528108520990033),
#   ('abbhorent', 0.011173100204707121)],
#  120: [('listen', 0.0372403485304862),
#   ('bmkdon', 0.030773050395455977),
#   ('facetim', 0.030773050395455977),
#   ('denver', 0.030773050395455977),
#   ('vrey', 0.030773050395455977),
#   ('listenz', 0.030773050395455977),
#   ('xxxxxx', 0.030773050395455977),
#   ('anything', 0.029293174005635678)],
#  121: [('free', 0.020849049462771555),
#   ('money', 0.020786496685502663),
#   ('give', 0.011695819390516147),
#   ('people', 0.011664360266388346),
#   ('ads', 0.011552995012963158),
#   ('you', 0.01038653247102469),
#   ('pay', 0.00974572906509033),
#   ('get', 0.009659708035361527)],
#  122: [('episodes', 0.07562398053499082),
#   ('oldest', 0.06888419219780414),
#   ('sorting', 0.061653235750401665),
#   ('unplayed', 0.03716111011198545),
#   ('newest', 0.036980981111663536),
#   ('episode', 0.035040385068617216),
#   ('order', 0.03284732415220179),
#   ('sort', 0.031231034057057457)],
#  123: [('widget', 0.10899746830716767),
#   ('exiting', 0.01965823156247374),
#   ('playing', 0.01958737374128203),
#   ('longer', 0.01864604900053608),
#   ('screen', 0.017741678612926665),
#   ('periodically', 0.017640830676887948),
#   ('disappears', 0.017608830902453684),
#   ('broke', 0.017110733462158027)],
#  124: [('storage', 0.1021795811679776),
#   ('space', 0.06191618919840846),
#   ('sd', 0.05276695584768491),
#   ('card', 0.042655649507820075),
#   ('size', 0.03714813883700549),
#   ('gigs', 0.027932525925006748),
#   ('stored', 0.024765425891336994),
#   ('move', 0.02465298143781201)],
#  125: [('files', 0.09803655909382052),
#   ('audio', 0.059096378560455215),
#   ('permission', 0.04356005022211022),
#   ('file', 0.043510178976994496),
#   ('open', 0.0395319843740199),
#   ('local', 0.03431263011271918),
#   ('opening', 0.030180987820150395),
#   ('opens', 0.024981570027709912)],
#  126: [('review', 0.0758701283731469),
#   ('deleted', 0.05077256061078457),
#   ('deleting', 0.04186650731204925),
#   ('reviews', 0.030726024340570264),
#   ('negative', 0.025176752406572547),
#   ('firestick', 0.020243514208674887),
#   ('keep', 0.019133685950468503),
#   ('real', 0.014989312966904882)],
#  127: [('weekly', 0.19175312276182013),
#   ('discover', 0.156832840861139),
#   ('discovery', 0.025184166765627077),
#   ('friendship', 0.022076318761957547),
#   ('afordeble', 0.022076318761957547),
#   ('suuuucks', 0.022076318761957547),
#   ('repteated', 0.022076318761957547),
#   ('pertained', 0.022076318761957547)],
#  128: [('premium', 0.014159763095107657),
#   ('esim', 0.014065871959728221),
#   ('paying', 0.011629794600295689),
#   ('fkn', 0.011562414100209487),
#   ('abilities', 0.011083878865615775),
#   ('support', 0.010984842207851758),
#   ('am', 0.010432808155015245),
#   ('months', 0.010251379790078652)],
#  129: [('content', 0.21074198402248792),
#   ('easy', 0.07286105787729329),
#   ('rich', 0.05905601831099623),
#   ('llus', 0.04615957559318397),
#   ('muchician', 0.04615957559318397),
#   ('cones', 0.042659374302105035),
#   ('use', 0.04229085248242969),
#   ('complete', 0.042204036588725964)],
#  130: [('knee', 0.07229596032569091),
#   ('effort', 0.05206742834064401),
#   ('tomorrow', 0.04543255466759231),
#   ('important', 0.044775337522434684),
#   ('unprecedented', 0.031193160298465618),
#   ('cheer', 0.028827836559101695),
#   ('broadly', 0.028827836559101695),
#   ('organic', 0.028827836559101695)],
#  131: [('daily', 0.12129543138768407),
#   ('mix', 0.0999881739539878),
#   ('phonk', 0.05862853343334402),
#   ('mixes', 0.050601559348465115),
#   ('genre', 0.036769331144737155),
#   ('same', 0.03530308603276062),
#   ('day', 0.033797650363542674),
#   ('sleep', 0.02094013905639943)],
#  132: [('listening', 0.13254751119366734),
#   ('best', 0.12736002935199275),
#   ('moosic', 0.06671237932445566),
#   ('rarest', 0.06671237932445566),
#   ('vocaliod', 0.06671237932445566),
#   ('pov', 0.05496779040603691),
#   ('generes', 0.053637759180325775),
#   ('xd', 0.0525133547097911)],
#  133: [('lossless', 0.16445695715711448),
#   ('hifi', 0.12967436695475246),
#   ('audio', 0.07086714627937107),
#   ('quality', 0.05316259286561499),
#   ('high', 0.0393522981691229),
#   ('low', 0.03331656237222265),
#   ('streaming', 0.030156888722795903),
#   ('podcastify', 0.026960460080974705)],
#  134: [('share', 0.13654961644454533),
#   ('links', 0.13206927992777218),
#   ('telegram', 0.09637210501907713),
#   ('copy', 0.05866237082827813),
#   ('sharing', 0.05802173779348638),
#   ('link', 0.032915303067217974),
#   ('pn', 0.02996588841787025),
#   ('appears', 0.02776463281703121)],
#  135: [('kpop', 0.13367763089745482),
#   ('pop', 0.052633847692820764),
#   ('recommnds', 0.022129772318281903),
#   ('maths', 0.022129772318281903),
#   ('thnk', 0.022129772318281903),
#   ('byt', 0.020451709713842123),
#   ('raps', 0.020451709713842123),
#   ('stans', 0.020451709713842123)],
#  136: [('gospel', 0.3044502551432524),
#   ('christian', 0.15152482426639258),
#   ('worship', 0.0602030830020938),
#   ('trending', 0.05522229352661984),
#   ('bryann', 0.042312944293751965),
#   ('praising', 0.042312944293751965),
#   ('secular', 0.042312944293751965),
#   ('lisyening', 0.042312944293751965)],
#  137: [('variety', 0.3734500397010395),
#   ('suggedtions', 0.08308723606773114),
#   ('alwsys', 0.08308723606773114),
#   ('enjoyably', 0.08308723606773114),
#   ('generes', 0.066803390979133),
#   ('recommendations', 0.05740187638826793),
#   ('round', 0.05029576830718479),
#   ('pleased', 0.04577401179314831)],
#  138: [('assistant', 0.11927348091225358),
#   ('commands', 0.05467883363356229),
#   ('google', 0.05139946578197838),
#   ('auto', 0.0467071780036205),
#   ('voice', 0.04551581921595237),
#   ('bixby', 0.040198864514023436),
#   ('android', 0.03401403978591258),
#   ('working', 0.032238548063582666)],
#  139: [('49', 0.02600701826326266),
#   ('undo', 0.021026974256712475),
#   ('stops', 0.017526248016910842),
#   ('premium', 0.016964117649164813),
#   ('sensitivity', 0.016831668448343325),
#   ('grates', 0.016831668448343325),
#   ('subscribed', 0.016231400685748198),
#   ('shuts', 0.015813732506718005)],
#  140: [('station', 0.24662339889882404),
#   ('stations', 0.10589303237922229),
#   ('clarity', 0.05388521486441131),
#   ('devout', 0.04211795376705265),
#   ('resembles', 0.04211795376705265),
#   ('feedom', 0.04211795376705265),
#   ('choices', 0.0340317467306768),
#   ('introduces', 0.03199645007915114)],
#  141: [('files', 0.24327012407834972),
#   ('local', 0.22988915796061454),
#   ('folder', 0.034285946563463024),
#   ('beole', 0.029106993526912185),
#   ('sync', 0.029012354082526517),
#   ('imported', 0.025608911837953968),
#   ('disappeared', 0.023951348515833696),
#   ('phone', 0.023118938197528836)],
#  142: [('about', 0.017563140527922256),
#   ('playlists', 0.017433815229130886),
#   ('djying', 0.016587288507169555),
#   ('conjure', 0.016587288507169555),
#   ('go0od', 0.016587288507169555),
#   ('sirens', 0.016587288507169555),
#   ('goesbumps', 0.016587288507169555),
#   ('fluidly', 0.016587288507169555)],
#  143: [('working', 0.1797975817958282),
#   ('properly', 0.11291513309199322),
#   ('tab', 0.09263731500241651),
#   ('pita', 0.05491854652856015),
#   ('s7', 0.05147155286968315),
#   ('fe', 0.05080816228093338),
#   ('assistance', 0.05080816228093338),
#   ('rebooting', 0.048153423217630005)],
#  144: [('smooth', 0.4159878254457437),
#   ('reliable', 0.0992159471801796),
#   ('satisfacción', 0.06976790814847653),
#   ('cream', 0.061383193260439284),
#   ('versatile', 0.05491854652856015),
#   ('ice', 0.05491854652856015),
#   ('crystal', 0.05019796755343072),
#   ('clear', 0.04830637539501077)],
#  145: [('podcasts', 0.055132044280058),
#   ('mercilessly', 0.023138217639115003),
#   ('eposides', 0.023138217639115003),
#   ('ahhahahahhahahh', 0.023138217639115003),
#   ('atall', 0.023138217639115003),
#   ('anddddd', 0.023138217639115003),
#   ('marketed', 0.021383686359029867),
#   ('yt', 0.020665031645796705)],
#  146: [('gaana', 0.166281568792347),
#   ('avalible', 0.0726430602723849),
#   ('wynk', 0.035044332054685316),
#   ('better', 0.027610749469640886),
#   ('than', 0.02442109896288409),
#   ('beats', 0.02255187075135203),
#   ('much', 0.019874932767803197),
#   ('are', 0.01946172413647926)],
#  147: [('gave', 0.03400711280774198),
#   ('ads', 0.03336999330014873),
#   ('stars', 0.03305541845899229),
#   ('pc', 0.031579475480147334),
#   ('ect', 0.02984026582873878),
#   ('pin', 0.0296432196626729),
#   ('rate', 0.02378764804434743),
#   ('juicy', 0.02302165231095825)],
#  148: [('looking', 0.1557727464134958),
#   ('find', 0.08364928695309984),
#   ('obscure', 0.0696795179549756),
#   ('everything', 0.06341981230967267),
#   ('fulfilling', 0.054332421061605046),
#   ('expecting', 0.04187220997844178),
#   ('expectations', 0.04058419083230114),
#   ('material', 0.0402973493302361)],
#  149: [('offline', 0.16440435839014877),
#   ('should', 0.05176564082730141),
#   ('allways', 0.045253512925694586),
#   ('meanwhile', 0.04317481388007927),
#   ('developed', 0.040920925119198),
#   ('bonus', 0.040920925119198),
#   ('content', 0.03733951931673611),
#   ('appreciated', 0.03448350273752586)],
#  150: [('games', 0.10532624775922478),
#   ('gaming', 0.06273129052882898),
#   ('while', 0.05665848188258657),
#   ('game', 0.04744119752015401),
#   ('spider', 0.046666055866391144),
#   ('multitasking', 0.04283769915226379),
#   ('listen', 0.04201112522413619),
#   ('aplication', 0.04160545461672407)],
#  151: [('removes', 0.02622966608679369),
#   ('playing', 0.02469612736035325),
#   ('latest', 0.024113732601020694),
#   ('notification', 0.022934326723504067),
#   ('prv', 0.02290625555751986),
#   ('reproductions', 0.02290625555751986),
#   ('blanked', 0.02290625555751986),
#   ('follen', 0.02290625555751986)],
#  152: [('shutting', 0.02327907797763201),
#   ('we', 0.01653560268952768),
#   ('lagging', 0.01623854416049377),
#   ('asia', 0.015570010166014354),
#   ('britches', 0.015570010166014354),
#   ('reinstalle', 0.015570010166014354),
#   ('pill', 0.015570010166014354),
#   ('youtubemusictryit', 0.015570010166014354)],
#  153: [('country', 0.06978160817345684),
#   ('uk', 0.04486059051395913),
#   ('location', 0.0366349446321492),
#   ('somalia', 0.030826847123418967),
#   ('countries', 0.020094792622479728),
#   ('change', 0.018275923829914213),
#   ('tanzania', 0.016678094831113915),
#   ('flexability', 0.016678094831113915)],
#  154: [('worst', 0.06347890121889907),
#   ('ever', 0.02534746736020361),
#   ('something', 0.015620595492844508),
#   ('compensating', 0.015283605296739841),
#   ('overreacting', 0.015283605296739841),
#   ('whink', 0.015283605296739841),
#   ('addfy', 0.015283605296739841),
#   ('hoorible', 0.015283605296739841)],
#  155: [('bluetooth', 0.0765632026562173),
#   ('permissions', 0.07225980942937787),
#   ('asking', 0.05808241672096919),
#   ('nearby', 0.0359945134469113),
#   ('permission', 0.026057995494352563),
#   ('open', 0.024830790568902132),
#   ('access', 0.024416476494888494),
#   ('pop', 0.023841819684271976)],
#  156: [('find', 0.05275608438519364),
#   ('lloved', 0.05192952254233196),
#   ('marriage', 0.05192952254233196),
#   ('olympics', 0.05192952254233196),
#   ('rythms', 0.05192952254233196),
#   ('interpretation', 0.05192952254233196),
#   ('productions', 0.047991796089868165),
#   ('search', 0.047438103975386885)],
#  157: [('updates', 0.056462950689078306),
#   ('update', 0.02584396375178801),
#   ('june', 0.02305668728132065),
#   ('updating', 0.022127081046383397),
#   ('23rd', 0.018134118983036556),
#   ('sheeple', 0.018134118983036556),
#   ('bottons', 0.018134118983036556),
#   ('spies', 0.018134118983036556)],
#  158: [('jre', 0.16270769165918503),
#   ('episodes', 0.038291336900267536),
#   ('support', 0.023611267099114028),
#   ('censorship', 0.02185414387156902),
#   ('openin', 0.020446523417115045),
#   ('discluded', 0.020446523417115045),
#   ('stink', 0.020446523417115045),
#   ('tantrum', 0.018896098684153907)],
#  159: [('skipping', 0.02020971030814037),
#   ('replaying', 0.02011169524815947),
#   ('playlist', 0.019550019169906264),
#   ('tracks', 0.018370898194197908),
#   ('jumping', 0.018076179118860003),
#   ('passed', 0.01779648506521343),
#   ('hiding', 0.01754119912022042),
#   ('list', 0.016798688841120207)],
#  160: [('mode', 0.07668978618422184),
#   ('offline', 0.07537307507732974),
#   ('handy', 0.034046366238709706),
#   ('toggle', 0.03341727962197911),
#   ('work', 0.029886421426610268),
#   ('deploy', 0.028121833746001308),
#   ('suberb', 0.028121833746001308),
#   ('deadzones', 0.028121833746001308)],
#  161: [('offline', 0.09578825365015185),
#   ('𝔹𝔼𝕊𝕋d', 0.03335618966222783),
#   ('stremming', 0.03335618966222783),
#   ('chloexhalle', 0.03335618966222783),
#   ('mumford', 0.03335618966222783),
#   ('mmod', 0.03335618966222783),
#   ('wowh', 0.03335618966222783),
#   ('ungodly', 0.029347439113567686)],
#  162: [('free', 0.10288928179370237),
#   ('version', 0.10230748542959815),
#   ('greaattt', 0.0643633518834537),
#   ('too', 0.057189356009115316),
#   ('ads', 0.057013599664221246),
#   ('monetization', 0.05662815716279962),
#   ('relentless', 0.05066429292423508),
#   ('overly', 0.04687231872395967)],
#  163: [('spanish', 0.027120267224462386),
#   ('ai', 0.026164926037261886),
#   ('good', 0.024753976422418267),
#   ('recommending', 0.024082163943251713),
#   ('lap', 0.020702343411315677),
#   ('siri', 0.020702343411315677),
#   ('over', 0.020316897898904448),
#   ('messenger', 0.01845732177849769)],
#  164: [('playlist', 0.018546335150022686),
#   ('unwanted', 0.015952413498670763),
#   ('hiddious', 0.013600589237277418),
#   ('keps', 0.013600589237277418),
#   ('randim', 0.013600589237277418),
#   ('specific', 0.013282431940212752),
#   ('shuffles', 0.012666458989693085),
#   ('songs', 0.012188976886145717)],
#  165: [('stress', 0.07251048731475637),
#   ('stressful', 0.05834658222737323),
#   ('relax', 0.04715075296801153),
#   ('littarly', 0.043730124246174285),
#   ('descend', 0.043730124246174285),
#   ('relieved', 0.043730124246174285),
#   ('comfy', 0.040414144075678456),
#   ('oddly', 0.0384746330962562)],
#  166: [('calm', 0.04288008748442702),
#   ('extovert', 0.0365583838698017),
#   ('introvert', 0.0365583838698017),
#   ('extrovert', 0.0365583838698017),
#   ('iget', 0.0365583838698017),
#   ('comforting', 0.033786224447267185),
#   ('everthing', 0.031014494186238986),
#   ('taste', 0.030899300038998493)],
#  167: [('𝑡ℎ𝑎𝑡', 0.073323996812622),
#   ('𝐛𝐮𝐭', 0.073323996812622),
#   ('𝗽𝗹𝗮𝘆𝗹𝗶𝘀𝘁', 0.073323996812622),
#   ('𝓲𝓽', 0.073323996812622),
#   ('𝐝𝐨𝐧', 0.073323996812622),
#   ('𝑖𝑠', 0.073323996812622),
#   ('𝑦𝑜𝑢', 0.073323996812622),
#   ('𝘁𝗵𝗲', 0.073323996812622)],
#  168: [('stop', 0.03698476559113165),
#   ('savanna', 0.030163683060892493),
#   ('mid', 0.02658460836598047),
#   ('dated', 0.025589516655312693),
#   ('excluding', 0.02485342338490778),
#   ('frustrates', 0.02196656521056856),
#   ('start', 0.02173582716996056),
#   ('rebooted', 0.020630518708295697)],
#  169: [('shuffle', 0.03550348977152184),
#   ('torture', 0.018689716466152886),
#   ('order', 0.015008972476006067),
#   ('ads', 0.013867984354884602),
#   ('biggest', 0.012427516726388988),
#   ('upsurd', 0.012300936699125742),
#   ('torturous', 0.012300936699125742),
#   ('manuely', 0.012300936699125742)],
#  170: [('free', 0.023567679710321504),
#   ('skips', 0.019153308246680118),
#   ('pick', 0.01707685219176482),
#   ('shuffle', 0.016716788910165224),
#   ('premium', 0.014369138552787744),
#   ('limited', 0.013159561233698625),
#   ('you', 0.012877109066247708),
#   ('get', 0.012053766335172869)],
#  171: [('amazon', 0.14279289086571775),
#   ('better', 0.051022145407777456),
#   ('far', 0.03636053522887024),
#   ('cheaper', 0.036057284657022876),
#   ('prime', 0.03561122393629273),
#   ('than', 0.03384597175654468),
#   ('fitbit', 0.027940581778344607),
#   ('desirable', 0.027354865381145933)],
#  172: [('downloading', 0.14289695035216018),
#   ('stuck', 0.06777947896816335),
#   ('unninstalled', 0.04663059167066543),
#   ('327', 0.04663059167066543),
#   ('smart', 0.04627705437417147),
#   ('470', 0.04309467403988161),
#   ('chews', 0.04309467403988161),
#   ('completing', 0.04102652202610992)],
#  173: [('freezing', 0.12114504658136749),
#   ('freezes', 0.08357198447203247),
#   ('everbody', 0.04968562418715763),
#   ('updates', 0.04565346601170396),
#   ('run', 0.04403439278592666),
#   ('exhausting', 0.04231958585436106),
#   ('consumption', 0.03824666449544783),
#   ('costly', 0.03645345339299637)],
#  174: [('friendly', 0.5977916201702461),
#   ('user', 0.3564387366454907),
#   ('convenient', 0.13328362741250316),
#   ('attractive', 0.129696747050283),
#   ('simple', 0.05429785600064419),
#   ('totally', 0.05388276015114325),
#   ('ok', 0.047477835576006475),
#   ('needs', 0.04094215812638018)],
#  175: [('ads', 0.02124518015603971),
#   ('lodaing', 0.01884452776793902),
#   ('git', 0.01884452776793902),
#   ('best', 0.017987962908477328),
#   ('personally', 0.017865689457874267),
#   ('lifesavers', 0.017415579611993397),
#   ('humming', 0.017415579611993397),
#   ('toddlers', 0.017415579611993397)],
#  176: [('collaborative', 0.23262118618522384),
#   ('people', 0.03909262386361187),
#   ('playlist', 0.03085480479070087),
#   ('collabrative', 0.024242960125863196),
#   ('consequently', 0.024242960125863196),
#   ('unverified', 0.024242960125863196),
#   ('add', 0.02393159379178884),
#   ('edit', 0.022959281106399887)],
#  177: [('addsಠಗಠ', 0.12025784167697928),
#   ('bronx', 0.12025784167697928),
#   ('endearing', 0.12025784167697928),
#   ('drill', 0.09466223151633395),
#   ('reducing', 0.08997337347860816),
#   ('balls', 0.08872070297274333),
#   ('dare', 0.08872070297274333),
#   ('motivation', 0.08872070297274333)],
#  178: [('lock', 0.12984664250695033),
#   ('screen', 0.0743770593406359),
#   ('s20', 0.051380419078913525),
#   ('fe', 0.04437246172534849),
#   ('galaxy', 0.034836881984834644),
#   ('wut', 0.03046531989150142),
#   ('android', 0.02831983756990055),
#   ('normally', 0.026811825795915102)],
#  179: [('podcasters', 0.056940435006160056),
#   ('misinformation', 0.03764440100440795),
#   ('tidal', 0.035298033621678306),
#   ('wants', 0.03132862390469555),
#   ('proven', 0.03068214199459136),
#   ('ek', 0.02855104962160426),
#   ('company', 0.028185435876145228),
#   ('monopoly', 0.026860322622679796)],
#  180: [('karaoke', 0.2597966670406433),
#   ('georgia', 0.07016853888289364),
#   ('feature', 0.06323819479453448),
#   ('translator', 0.03638551274713822),
#   ('amajin', 0.03638551274713822),
#   ('nicer', 0.03255352758027774),
#   ('worldwide', 0.03255352758027774),
#   ('could', 0.03243975352022862)],
#  181: [('wi', 0.03195390647542769),
#   ('fi', 0.030466944280143828),
#   ('podcasts', 0.023386122734775465),
#   ('happens', 0.0161559945433228),
#   ('podcast', 0.015580435024841494),
#   ('instance', 0.015165410059382916),
#   ('excel', 0.014512983009994497),
#   ('cloud', 0.013873437140370344)],
#  182: [('relaxing', 0.16499948469724754),
#   ('entertaining', 0.13606065308975507),
#   ('entertainment', 0.11670687901200334),
#   ('story', 0.11425380559996405),
#   ('pt', 0.11011561406566778),
#   ('gaffey', 0.11011561406566778),
#   ('picnics', 0.11011561406566778),
#   ('enlightening', 0.11011561406566778)],
#  183: [('nice', 0.0950900633116423),
#   ('gud', 0.06158805901778286),
#   ('awsome', 0.05208368008755752),
#   ('millions', 0.051025898480754485),
#   ('find', 0.046894297231283244),
#   ('recommendation', 0.04442700253647316),
#   ('good', 0.04372130900582966),
#   ('line', 0.042768752571689495)],
#  184: [('best', 0.0609607593909189),
#   ('levi', 0.05676767681646227),
#   ('yair', 0.05676767681646227),
#   ('leat', 0.05676767681646227),
#   ('sabbah', 0.05676767681646227),
#   ('shai', 0.05676767681646227),
#   ('eliyabu', 0.05676767681646227),
#   ('ever', 0.05230429772740427)],
#  185: [('mighty', 0.05376232922029662),
#   ('fluent', 0.05376232922029662),
#   ('instantaneously', 0.04968562418715763),
#   ('temperamental', 0.04730116657127968),
#   ('swings', 0.04560955027388086),
#   ('speaks', 0.04153473799103419),
#   ('spirit', 0.04022339049631894),
#   ('lift', 0.0391521721106016)],
#  186: [('bad', 0.05766398123909935),
#   ('words', 0.039349855523203456),
#   ('discusting', 0.03810994463088885),
#   ('cousin', 0.03482641235878972),
#   ('blast', 0.030183013795741894),
#   ('um', 0.030183013795741894),
#   ('another', 0.028718905889506582),
#   ('shift', 0.02807247756874241)],
#  187: [('version', 0.10259648962572696),
#   ('free', 0.06753595384301574),
#   ('obstacle', 0.051636135409324435),
#   ('theifs', 0.051636135409324435),
#   ('torn', 0.04772065599896495),
#   ('unenjoyable', 0.0454304989667658),
#   ('fools', 0.04254569087924891),
#   ('damn', 0.042003950460931194)],
#  188: [('subscription', 0.192731601038925),
#   ('sister', 0.05932161688404477),
#   ('gift', 0.05398012920156319),
#   ('subscriptions', 0.05037295988128777),
#   ('purchased', 0.04920575896671019),
#   ('she', 0.04748368116664842),
#   ('alright', 0.04446226792812553),
#   ('glad', 0.042167692492997906)],
#  189: [('dipped', 0.033114478142936325),
#   ('inviting', 0.030603464173249266),
#   ('spice', 0.030603464173249266),
#   ('reject', 0.027284736542127017),
#   ('choices', 0.026756844349843715),
#   ('degree', 0.026624539882987793),
#   ('food', 0.025156629228897814),
#   ('exposed', 0.024430338499740918)]}

# %% [markdown]
# ### post processing for topic modelling

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
topic_words = []
for i in topics:
    temp_word = []
    for j in gen_topic[i]:
        temp_word.append(j[0])
    l = ' '.join(list(set(temp_word)))
    topic_words.append(l)

# %%
topic_words
# Out:
# ['music and the you it to is app',
#  'stars rating give because five rate would star',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'play listen want songs playlist plays song random',
#  'android playback pause player disappearing disappear controls control',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'update pause control playing disappearing disappears bar bottom',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'music and the you it to is app',
#  'music amazing provide great rock ever experience best',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet downloaded online when connection mode download offline',
#  'internet data wifi connection working no connected network',
#  'theme option mode wonderfully light dark themes black',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'me email out logged login log password account',
#  'music and the you it to is app',
#  '30 adds many there much are add too',
#  'internet downloaded online when connection mode download offline',
#  'play listen want songs playlist plays song random',
#  'spotify music great love use easy best app',
#  'spanish many depravity commercials no love commercial too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'degree dipped reject food exposed choices spice inviting',
#  'music service great platform ever stream streaming best',
#  'me email out logged login log password account',
#  'update pause control playing disappearing disappears bar bottom',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  '30 after many ads ad are minutes too',
#  'stars rating give because five rate would star',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'per only skip want you playlist skips hour',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play over shuffling same playlist turn button shuffle',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'navigate navigation far use very friendly tyriuggt easy',
#  'music and the you it to is app',
#  'search here all find available songs searched song',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'pc version want can song desktop on mobile',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'me email out logged login log password account',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'autoplay auto pioneer kenwood bluetooth connect connected car',
#  'music and the you it to is app',
#  'music amazing provide great rock ever experience best',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'rebooting fe assistance properly tab working s7 pita',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  'worth version you without premium pay for free',
#  'screen opening working logo stuck black open tried',
#  'added queued album option from next queue add',
#  'ever worst bad ads thn mtlbb krta affiliation',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'rebooting fe assistance properly tab working s7 pita',
#  'subscribe unable method premium connect plan card payment',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'screen opening working logo stuck black open tried',
#  'landscape layout buttons pause design ui left button',
#  'spotify music great love use easy best app',
#  'service round great year worth customer misinformation excellent',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening logo cache reinstalling stuck open tried',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'screen opening working logo stuck black open tried',
#  'spotify music great love use easy best app',
#  '30 after many ads ad are minutes too',
#  'artists images artwork album art cover artist covers',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'problems glitching great glitch glitchy glitches works sometimes',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'play over shuffling same playlist turn button shuffle',
#  'per only skip want you playlist skips hour',
#  'bug player disappearing fixed vanishing visible disappears restart',
#  '30 after many ads ad are minutes too',
#  '30 adds many there much are add too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet data wifi connection working no connected network',
#  'worth version you without premium pay for free',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening logo cache reinstalling stuck open tried',
#  'mounam vary minea pahari assoommm ets aap best',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  '30 adds many there much are add too',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  's22 opening s21 glitchy slower s22u samsung ultra',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'service cancel month premium subscription for app bugs',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'all playlists my fine anything playlist empty gone',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'artists available songs some missing albums are not',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'great clear quality audio good sound excellent sounds',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'great truth casts kincade cast revealed pod cavern',
#  'screen opening logo cache reinstalling stuck open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'fix crash constantly keeps crashing update app crashes',
#  'navigate navigation far use very friendly tyriuggt easy',
#  '30 after many ads ad are minutes too',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'better apple music 10000000000 here 2years than 1yr',
#  'music and the you it to is app',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'all playlists my fine anything playlist empty gone',
#  'music and the you it to is app',
#  'level down turning speaker adjust volume low equalizer',
#  'listening great for and podcasts to podcast episode',
#  'search here all find available songs searched song',
#  'me email out logged login log password account',
#  'lyrics english tamil telugu language korean kannada languages',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'lists playlists make own playlist create easy love',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'collection nice songs excellent of good collections best',
#  'lists playlists make own playlist create easy love',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'lists playlists make own playlist create easy love',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'search here all find available songs searched song',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'amazing excitingly expressd generously words exceptional expeeience word',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'or previous skip ahead track next skips song',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening logo cache reinstalling stuck open tried',
#  'music and the you it to is app',
#  'lyrics english tamil telugu language korean kannada languages',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'play over shuffling same playlist turn button shuffle',
#  'music and the you it to is app',
#  's22 opening s21 glitchy slower s22u samsung ultra',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  '𝐛𝐮𝐭 𝑡ℎ𝑎𝑡 𝗽𝗹𝗮𝘆𝗹𝗶𝘀𝘁 𝓲𝓽 𝘁𝗵𝗲 𝑦𝑜𝑢 𝐝𝐨𝐧 𝑖𝑠',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'spotify live survive couldn without life love would',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'spotify music great love use easy best app',
#  'space downloaded deleting deletes download redownload downloads redownloading',
#  'music and the you it to is app',
#  'autoplay auto pioneer kenwood bluetooth connect connected car',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'your playlists algorithm recommendations follow algorithms create tastes',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'update pause control playing disappearing disappears bar bottom',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'exiting screen widget playing longer periodically broke disappears',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'search here all find available songs searched song',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'lists playlists make own playlist create easy love',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'landscape layout buttons pause design ui left button',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'listening great for and podcasts to podcast episode',
#  'listening great for and podcasts to podcast episode',
#  'search here all find available songs searched song',
#  'referral music variety applications application program ever best',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'lists playlists make own playlist create easy love',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet data wifi connection working no connected network',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'better fitbit desirable amazon far prime than cheaper',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'screen phone lock locked playing unlock stops last',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'lists playlists make own playlist create easy love',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'while removed view mode removing driving car thing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'better spotify years switched than pandora used love',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'play listen want songs playlist plays song random',
#  'worth version you without premium pay for free',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'better spotify edition than fell spikes distortion youtube',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'bonus should allways appreciated content meanwhile offline developed',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'screen opening logo cache reinstalling stuck open tried',
#  'added queued album option from next queue add',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'listening great for and podcasts to podcast episode',
#  'play listen want songs playlist plays song random',
#  'play listen want songs playlist plays song random',
#  'internet data wifi connection working no connected network',
#  '30 after many ads ad are minutes too',
#  'spotify ddlc amazing doki exsperience awesome club literature',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'unlinking alexa compatible echo amazon connect devices device',
#  'play listen want songs playlist plays song random',
#  'screen opening logo cache reinstalling stuck open tried',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'group scan link join sessions scanning device session',
#  'music and the you it to is app',
#  'spotify bank method account premium plan card payment',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'play over shuffling same playlist turn button shuffle',
#  'better more way than pandora much was this',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'lists playlists make own playlist create easy love',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'great clear quality audio good sound excellent sounds',
#  '30 after many ads ad are minutes too',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  'search here all find available songs searched song',
#  'play listen want songs playlist plays song random',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'spotify music great love use easy best app',
#  'play listen want songs playlist plays song random',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'worth version you without premium pay for free',
#  'spotify ddlc amazing doki exsperience awesome club literature',
#  'spotify music great love use easy best app',
#  'listening perfect very efficient tickle good fancy for',
#  'landscape layout buttons pause design ui left button',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'order playlists by playlist rearrange sort option sorting',
#  'bring previews preview feature before playlist adding add',
#  'play over shuffling same playlist turn button shuffle',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'still lyrics available feature the showing but see',
#  'play listen want songs playlist plays song random',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'effort knee broadly cheer organic unprecedented important tomorrow',
#  'music and the you it to is app',
#  'calm sad helps relaxing relax depressed mood stress',
#  'spotify music great love use easy best app',
#  '30 after many ads ad are minutes too',
#  'subscribe unable method premium connect plan card payment',
#  'spotify work phone why properly working not tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'me email out logged login log password account',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play over shuffling same playlist turn button shuffle',
#  'me email out logged login log password account',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'charged cancel account they subscription card payment unsubscribe',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  '30 after many ads ad are minutes too',
#  'music amazing provide great rock ever experience best',
#  'listening great for and podcasts to podcast episode',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 adds many there much are add too',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'worth version you without premium pay for free',
#  'list my heart removed songs from liked added',
#  'music and the you it to is app',
#  'update pause control playing disappearing disappears bar bottom',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'all playlists my fine anything playlist empty gone',
#  'music and the you it to is app',
#  'still lyrics available feature the showing but see',
#  'me email out logged login log password account',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'internet data wifi connection working no connected network',
#  'stars rating give because five rate would star',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'ever worst bad ads thn mtlbb krta affiliation',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'artists images artwork album art cover artist covers',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'screen opening working logo stuck black open tried',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'listening best generes xd rarest pov moosic vocaliod',
#  'play over shuffling same playlist turn button shuffle',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'search here all find available songs searched song',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'worth version you without premium pay for free',
#  'autoplay auto pioneer kenwood bluetooth connect connected car',
#  'music and the you it to is app',
#  'external sd location internal downloads reboot card storage',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'lists playlists make own playlist create easy love',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'internet downloaded online when connection mode download offline',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'uk country flexability somalia location tanzania change countries',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'stars juicy pc rate gave ads pin ect',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'added queued album option from next queue add',
#  'better spotify years switched than pandora used love',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'effort knee broadly cheer organic unprecedented important tomorrow',
#  'listening great for and podcasts to podcast episode',
#  'spotify bank method account premium plan card payment',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'android finally ios gesture add feature queue swipe',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'better more way than pandora much was this',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'problems glitching great glitch glitchy glitches works sometimes',
#  'music and the you it to is app',
#  'forever load connection takes loading slower slow optimize',
#  'play listen want songs playlist plays song random',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'music and the you it to is app',
#  'great clear quality audio good sound excellent sounds',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'play listen want songs playlist plays song random',
#  'spotify music great love use easy best app',
#  'collection nice songs excellent of good collections best',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'screen opening logo cache reinstalling stuck open tried',
#  'play listen want songs playlist plays song random',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'group scan link join sessions scanning device session',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'update pause control playing disappearing disappears bar bottom',
#  'listening great for and podcasts to podcast episode',
#  'play listen want songs playlist plays song random',
#  'worth version you without premium pay for free',
#  'hide mistake discovery unhide option hiding tapped hidden',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'bug player disappearing fixed vanishing visible disappears restart',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'internet downloaded online when connection mode download offline',
#  'spotify music great love use easy best app',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'internet downloaded online when connection mode download offline',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music amazing provide great rock ever experience best',
#  'or previous skip ahead track next skips song',
#  'screen opening working logo stuck black open tried',
#  'music service great platform ever stream streaming best',
#  'music and the you it to is app',
#  'order playlists by playlist rearrange sort option sorting',
#  'unable withouy some download subsecribe premium paid evenn',
#  'lists playlists make own playlist create easy love',
#  'spotify music great love use easy best app',
#  'order playlists by playlist rearrange sort option sorting',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'mounam vary minea pahari assoommm ets aap best',
#  'worth version you without premium pay for free',
#  'music and the you it to is app',
#  'internet playlists downloaded forever load takes loading slow',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'fix crash constantly keeps crashing update app crashes',
#  'referral music variety applications application program ever best',
#  'spotify music great love use easy best app',
#  'support months esim abilities premium am paying fkn',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'worth version you without premium pay for free',
#  'play over shuffling same playlist turn button shuffle',
#  'spotify playlists my any playlist empty working nothing',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'search here all find available songs searched song',
#  'spotify bank method account premium plan card payment',
#  'landscape layout buttons pause design ui left button',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'autoplay auto pioneer kenwood bluetooth connect connected car',
#  'whole album option single download particular entire individual',
#  'still lyrics available feature the showing but see',
#  'worth version you without premium pay for free',
#  'listening great for and podcasts to podcast episode',
#  'play listen want songs playlist plays song random',
#  'listening great for and podcasts to podcast episode',
#  'internet data wifi connection working no connected network',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'screen opening working logo stuck black open tried',
#  'music and the you it to is app',
#  'spotify live survive couldn without life love would',
#  'screen opening working logo stuck black open tried',
#  'music service great platform ever stream streaming best',
#  'yair eliyabu ever shai sabbah leat levi best',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'problems years tonuninstall moment naver had giid app',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  '30 after many ads ad are minutes too',
#  'listening great for and podcasts to podcast episode',
#  'listening great for and podcasts to podcast episode',
#  'order newest unplayed oldest sort episodes sorting episode',
#  '30 after many ads ad are minutes too',
#  'spotify music great love use easy best app',
#  'collection nice songs excellent of good collections best',
#  'listening great for and podcasts to podcast episode',
#  'spotify music great love use easy best app',
#  'play over shuffling same playlist turn button shuffle',
#  'music and the you it to is app',
#  'music service great platform ever stream streaming best',
#  'play listen want songs playlist plays song random',
#  'play listen want songs playlist plays song random',
#  'still lyrics available feature the showing but see',
#  'music and the you it to is app',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'fix crash constantly keeps crashing update app crashes',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'list my heart removed songs from liked added',
#  'screen opening logo cache reinstalling stuck open tried',
#  'search here all find available songs searched song',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'bug player disappearing fixed vanishing visible disappears restart',
#  'that extra songs playlist trim it added add',
#  'listening great for and podcasts to podcast episode',
#  'music and the you it to is app',
#  'stars rating give because five rate would star',
#  'spotify music great love use easy best app',
#  'added queued album option from next queue add',
#  'randomly stopping stop pause playing keeps stops pausing',
#  'music and the you it to is app',
#  'spotify play stop pause playing disappearing disappears bar',
#  'spotify music great love use easy best app',
#  'spotify music great love use easy best app',
#  'update pause control playing disappearing disappears bar bottom',
#  'added queued album option from next queue add',
#  'massive extensive library musical large overplay excellent chart',
#  'spotify music great love use easy best app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'music and the you it to is app',
#  'listening great for and podcasts to podcast episode',
#  'play listen want songs playlist plays song random',
#  'spotify music great love use easy best app',
#  'screen opening working logo stuck black open tried',
#  'me email out logged login log password account',
#  '30 after many ads ad are minutes too',
#  'music and the you it to is app',
#  'internet downloaded online when connection mode download offline',
#  'lyrics english tamil telugu language korean kannada languages',
#  'music and the you it to is app',
#  'music amazing provide great rock ever experience best',
#  ...]

# %%
clean_topics = []
for i in topic_words:
    filter_sent = []
    temp = i.split()
    for w in temp:
        if w not in stop_words:
            filter_sent.append(w)
    lemma_words = []
    for w in filter_sent:
        lemma_words.append(lemmatizer.lemmatize(w))
    clean_topics.append(' '.join(list(set(lemma_words))))

# %% [markdown]
# ### add topic column to dataframe

# %%
df['topics'] = pd.DataFrame(clean_topics, columns=['topics'])['topics']

# %%
df
# Out:
#             Time_submitted  ...                                             topics
# 0      2022-07-09 15:00:00  ...                                          music app
# 1      2022-07-09 14:21:22  ...                   rating give five rate would star
# 2      2022-07-09 13:27:32  ...                                          music app
# 3      2022-07-09 13:26:45  ...         spotify music great easy use love best app
# 4      2022-07-09 13:20:49  ...              play listen want playlist song random
# ...                    ...  ...                                                ...
# 61589  2022-01-01 03:01:29  ...          still available lyric feature showing see
# 61590  2022-01-01 02:13:40  ...             worth version without premium pay free
# 61591  2022-01-01 01:02:29  ...                                          music app
# 61592  2022-01-01 00:49:23  ...                                          music app
# 61593  2022-01-01 00:19:09  ...  internet take forever downloaded load playlist...
#
# [61594 rows x 3 columns]
